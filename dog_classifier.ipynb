# %% [markdown]
# <a href="https://colab.research.google.com/github/pds2021/a5-chiZhang109/blob/assignment_5/dog_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**App - Dog Classifier**
#
# shiba? husky ? or an akita ?
#
# here you can select your picture and we help classify your dog.

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
download_url('https://github.com/pds2021/a5-chiZhang109/releases/download/v1.0/export.pkl', 'dog_classifier.pkl')
learn_inf = load_learner('dog_classifier.pkl', cpu=True)
btn_upload = widgets.FileUpload()
btn_run = widgets.Button(description='Classify')
out_pl = widgets.Output()
lbl_pred = widgets.Label()

def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(512,512))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)
VBox([widgets.Label('Select your dog!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
